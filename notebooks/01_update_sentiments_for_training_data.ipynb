# %%
# !python ../scripts/update_sentiments_for_training_data.py --training-dir ../dataset/training_data --sentiment-dir ../dataset/sentiment
# Out:
# ...
# Update Sentiment Scores in Training Data
# ...
# Training data directory: ../dataset/training_data
# Sentiment data directory: ../dataset/sentiment
#
# ...
# Processing AAPL
# ...
# Loading training data from: ../dataset/training_data/AAPL_data_model_training.csv
# Original dataset shape: (1257, 24)
# Date range: 2020-01-02 00:00:00 to 2024-12-30 00:00:00
# Original sentiment range: [-0.3709, 0.9884]
# Original sentiment mean: 0.5802
# Loading sentiment from: ../dataset/sentiment/news_sentiment_finbert_tone_weighted_aapl.csv
# Sentiment data shape: (1825, 2)
# Sentiment date range: 2020-01-01 00:00:00 to 2024-12-31 00:00:00
# Missing sentiment values: 0 out of 1257
#
# Sentiment values changed: 0 out of 1257
# Updated sentiment range: [-0.3709, 0.9884]
# Updated sentiment mean: 0.5802
#
# ✓ Updated and saved to: ../dataset/training_data/AAPL_data_model_training.csv
#   Columns: 23
#   Rows: 1257
#
# ...
# Processing META
# ...
# Loading training data from: ../dataset/training_data/META_data_model_training.csv
# ...
